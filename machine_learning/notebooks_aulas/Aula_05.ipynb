# %% [markdown]
# # **Aprendizado de Máquina** <BR>**Aula 05** - Regressão logística binária e problemas de classificação

# %% [markdown]
# # **Ex1 e 2** Classificação de origens dos automóveis e normalização de atributos

# %% [markdown]
# ## **1)** Importação de bibliotecas e classes

# %%
# Bibliotecas de uso geral (cálculos, manipulação de dados e geração de gráficos)
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Bibliotecas específicas de Machine Learning
from sklearn.model_selection import train_test_split    # Divisão de dados (treino/teste)
from sklearn.model_selection import cross_val_score     # Validação cruzada k-folds
from sklearn.linear_model import LogisticRegression     # Regressão logística

# %% [markdown]
# ## **2)** Leitura de dados e exploração inicial

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# OBSERVAÇÕES: "monte" o disco e ajuste o caminho
# do arquivo de dados antes da executar esta célula!

caminho_arquivo = "/content/drive/MyDrive/Colab Notebooks/Aula2_ML/A02Ex1_carros.csv"
df = pd.read_csv(caminho_arquivo)
display(df)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70     USA  chevrolet chevelle malibu
# 1            70     USA          buick skylark 320
# 2            70     USA         plymouth satellite
# 3            70     USA              amc rebel sst
# 4            70     USA                ford torino
# ..          ...     ...                        ...
# 387          82     USA            ford mustang gl
# 388          82  Europe                  vw pickup
# 389          82     USA              dodge rampage
# 390          82     USA                ford ranger
# 391          82     USA                 chevy s-10
#
# [392 rows x 9 columns]

# %% [markdown]
# ### **2.1)** Características gerais

# %%
# Contagem de classes da resposta/target
df['origin'].value_counts()
# Out:
# origin
# USA       245
# Asia       79
# Europe     68
# Name: count, dtype: int64

# %% [markdown]
# ## **3)** Pré-processamento e seleção de variáveis

# %% [markdown]
# ### **3.1)** Seleção de atributos e resposta

# %%
X = df.drop(columns = ['origin', 'car name'])  # Atributos: todos, exceto origens e nome
y = df['origin']                                         # Resposta/target: origem binária

# %%
# Checagem dos atributos
X.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model year
# 0  18.0          8         307.0         130    3504          12.0          70
# 1  15.0          8         350.0         165    3693          11.5          70
# 2  18.0          8         318.0         150    3436          11.0          70
# 3  16.0          8         304.0         150    3433          12.0          70
# 4  17.0          8         302.0         140    3449          10.5          70

# %% [markdown]
# ### **3.2)** Divisão dos dados de treino e teste

# %%
# Parâmetros da função 'train_test_split':
#   X,y = arrays (ou equivalentes) das variáveis independentes (X) e dependente (y)
#   train_size/test_size = percentual de dados de treino/teste. Padrão: 75% (treino) e 25% (teste)
#   random_state = controle da aleatoriedade da divisão (valor inteiro)
#     IMPORTANTE: sem o controle do parâmetro 'random_state', diferentes partições
#     do conjunto de dados serão retornadas a cada execução da função de divisão
#   stratify: variável que define a estratificação de classes a ser mantida
#
# Retorno:
#   Tupla (4 valores) dos atributos de treino e teste e respostas (idem)

X_treino, X_teste, y_treino, y_teste = train_test_split(X,y, random_state = 42,
                                                        stratify = y)

# %% [markdown]
# ### **3.3)** Normalização de atributos

# %%
# Padronização dos dados (atributos) de treino e teste
# segundo a média e o desvio padrão do conjunto de TREINO

# Importação da biblioteca necessária para padronização de atributos
from sklearn.preprocessing import StandardScaler

# Criação de instância e treinamento de um objeto "escalonador"
escalonador = StandardScaler()
escalonador.fit(X_treino)

# Padronização dos dados de treino e teste
X_treino_Padr = escalonador.transform(X_treino)
X_teste_Padr = escalonador.transform(X_teste)

# Conversão dos conjuntos padronizados (arrays) em DataFrames
X_treino_Padr = pd.DataFrame(data = X_treino_Padr, columns = X_treino.columns)
X_teste_Padr = pd.DataFrame(data = X_teste_Padr, columns = X_treino.columns)

# %%
# checagem dos dados padronizados
X_treino_Padr.head()
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0 -1.169472   1.440857      1.137095    1.111028  1.417813     -0.370424
# 1 -1.042233   0.289737      0.497374   -0.156108  0.377715      0.523703
# 2 -0.978614   1.440857      1.447547    0.908286  1.206561     -0.441954
# 3 -0.507830   0.289737      0.318628   -0.029394  0.607437      1.310535
# 4 -0.787755   1.440857      0.591450    0.097319  1.213488      1.239005
#
#    model year
# 0   -0.793401
# 1   -0.522169
# 2    0.833994
# 3    0.562761
# 4    0.291529

# %%
# Resumo estatístico dos dados padronizados
X_treino_Padr.describe()
# Out:
#                 mpg     cylinders  displacement    horsepower        weight  \
# count  2.940000e+02  2.940000e+02  2.940000e+02  2.940000e+02  2.940000e+02
# mean  -5.256566e-16  7.250436e-17  1.812609e-17 -1.450087e-16  6.646233e-17
# std    1.001705e+00  1.001705e+00  1.001705e+00  1.001705e+00  1.001705e+00
# min   -1.805666e+00 -1.436941e+00 -1.196004e+00 -1.473929e+00 -1.611286e+00
# 25%   -8.513748e-01 -8.613817e-01 -8.479211e-01 -7.643328e-01 -8.782535e-01
# 50%   -1.515613e-01 -8.613817e-01 -4.339842e-01 -2.828212e-01 -2.150607e-01
# 75%    7.391104e-01  1.440857e+00  9.865721e-01  6.421878e-01  7.358620e-01
# max    2.724036e+00  1.440857e+00  2.425944e+00  3.011731e+00  2.460221e+00
#
#        acceleration    model year
# count  2.940000e+02  2.940000e+02
# mean  -2.779334e-16 -7.461907e-16
# std    1.001705e+00  1.001705e+00
# min   -2.516330e+00 -1.607099e+00
# 25%   -6.923101e-01 -7.934011e-01
# 50%   -1.277325e-02  2.029631e-02
# 75%    5.862922e-01  8.339938e-01
# max    3.313381e+00  1.647691e+00

# %% [markdown]
# ## **4)** Treinamento do <u>classificador</u> (modelo de regressão logística binária)

# %%
clf_RL = LogisticRegression()   # Cria instância de um classificador por reg. log. binária
clf_RL.fit(X_treino_Padr,y_treino)   # Treina o classificador
# Out:
# LogisticRegression()

# %%
# Exibe o total de iterações do algoritmo de treinamento
print("Total de iterações =",clf_RL.n_iter_)
# Out:
# Total de iterações = [29]

# %% [markdown]
# ## **5)** Validação cruzada *hold-out*

# %% [markdown]
# ### **5.1)** Avaliação <u>preliminar</u> do classificador via acurácia de ressubstituição

# %%
# Importação da biblioteca necessária para o cálculo da acurácia
from sklearn.metrics import accuracy_score

# Cálculo das previsões do classificador para os dados de treino (ressubstituição)
y_prev_treino = clf_RL.predict(X_treino_Padr)

# Acurácia "preliminar" (ressubstituição)
acc_prelim = accuracy_score(y_true = y_treino,y_pred = y_prev_treino)
print("Acurácia preliminar (dados de treino) =",acc_prelim)
# Out:
# Acurácia preliminar (dados de treino) = 0.7619047619047619

# %% [markdown]
# ### **5.2)** Avaliação da capacidade de generalização via acurácia de teste

# %%
# Cálculo das previsões do classificador para os dados de treino (ressusbstituição)
y_prev_teste = clf_RL.predict(X_teste_Padr)

# e a acurácia correspondente
y_prev_teste = clf_RL.predict(X_teste_Padr)
acc_teste = accuracy_score(y_true = y_teste,y_pred = y_prev_teste)
print("Acurácia =",acc_teste)
# Out:
# Acurácia = 0.8163265306122449

# %% [markdown]
# ### **5.3)** Matriz de confusão e relatório de métricas

# %%
# Exibição "básica" da matriz de confusão
# Importação da função de cálculo
from sklearn.metrics import confusion_matrix

confusion_matrix(y_true = y_teste,y_pred = y_prev_teste)
# Out:
# array([[14,  4,  2],
#        [ 6, 10,  1],
#        [ 3,  2, 56]])

# %%
# Representação "gráfica" da matriz de confusão
# Importação da função de exibição
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_true = y_teste,
                                        y_pred = y_prev_teste)
plt.show()

# %%
# Relatório das métricas de qualidade
from sklearn.metrics import classification_report

print(classification_report(y_true = y_teste,y_pred = y_prev_teste,digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#         Asia     0.6087    0.7000    0.6512        20
#       Europe     0.6250    0.5882    0.6061        17
#          USA     0.9492    0.9180    0.9333        61
#
#     accuracy                         0.8163        98
#    macro avg     0.7276    0.7354    0.7302        98
# weighted avg     0.8234    0.8163    0.8190        98

# %% [markdown]
# ## **6)** Validação k-folds

# %%
# Importação da bilioteca necessária
from sklearn.model_selection import cross_val_score

# Parâmetros da função 'cross_val_score':
#   estimator = estimador de alguma classe reconhecida (Scikit-Learn)
#   X,y = atributos (X) e resposta (y)
#   cv = número [inteiro] de partições (k); valor padrão: k = 5
#   scoring = texto indicativo da métrica de qualidade a ser calculada (teste)
#     https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-string-names
#
# Retorno:
#   array (Numpy) com os k valores da métrica selecionada

# Executa a validação cruzada k-folds, com k = 5, avaliando a métrica de acurácia
aval = cross_val_score(clf_RL,X_treino_Padr,y_treino,cv = 5,scoring = 'accuracy')

# Calcula o coeficiente de variação das avaliações = desvio padrão/média
# Critério:
# Até 20%: variação baixa
# De 20% a 60%: variação moderada
# Acima de 60%: variação alta

print("Valores de acurácia obtidos:",aval)
print("")   # "Imprime" uma linha em branco
print("Acurácia médio =",aval.mean())
print("Coeficiente de variação (%) =",100*aval.std(ddof = 1)/aval.mean())
# Out:
# Valores de acurácia obtidos: [0.72881356 0.76271186 0.72881356 0.77966102 0.74137931]
#
# Acurácia médio = 0.7482758620689655
# Coeficiente de variação (%) = 2.987210899348295

# %% [markdown]
# ---
# **Fim do Ex 1 e 2 (aula 5)**

# %% [markdown]
# # **Exercício 3**. Classificação via classificador *KNN*

# %% [markdown]
# ##  **4)** treinamento do classificador KNN

# %%
# importação da biblioteca necessária para treinamento do classificador KNN
from sklearn.neighbors import KNeighborsClassifier

# %%
# treinamento d classificador KNN, com K = 5 e dados PADRONIZADOS
clf_KNN = KNeighborsClassifier(n_neighbors = 5)
clf_KNN.fit(X_treino_Padr,y_treino)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## **5)** Validação cruzada *hold-out*

# %% [markdown]
# ### **5.1)** Avaliação <u>preliminar</u> do classificador via acurácia de ressubstituição

# %%
# Importação da biblioteca necessária para o cálculo da acurácia
from sklearn.metrics import accuracy_score

# Cálculo das previsões do classificador para os dados de treino (ressubstituição)
y_prev_treino = clf_KNN.predict(X_treino_Padr)

# Acurácia "preliminar" (ressubstituição)
acc_prelim = accuracy_score(y_true = y_treino,y_pred = y_prev_treino)
print("Acurácia preliminar (dados de treino) =",acc_prelim)
# Out:
# Acurácia preliminar (dados de treino) = 0.8095238095238095

# %% [markdown]
# ### **5.2)** Avaliação da capacidade de generalização via acurácia de teste

# %%
# Cálculo das previsões do classificador para os dados de treino (ressusbstituição)
y_prev_teste = clf_KNN.predict(X_teste_Padr)

# e a acurácia correspondente
y_prev_teste = clf_KNN.predict(X_teste_Padr)
acc_teste = accuracy_score(y_true = y_teste,y_pred = y_prev_teste)
print("Acurácia =",acc_teste)
# Out:
# Acurácia = 0.7142857142857143

# %% [markdown]
# ### **5.3)** Matriz de confusão e relatório de métricas

# %%
# Exibição "básica" da matriz de confusão
# Importação da função de cálculo
from sklearn.metrics import confusion_matrix

confusion_matrix(y_true = y_teste,y_pred = y_prev_teste)
# Out:
# array([[11,  6,  3],
#        [ 7,  9,  1],
#        [ 7,  4, 50]])

# %%
# Representação "gráfica" da matriz de confusão
# Importação da função de exibição
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_true = y_teste,
                                        y_pred = y_prev_teste)
plt.show()

# %%
# Relatório das métricas de qualidade
from sklearn.metrics import classification_report

print(classification_report(y_true = y_teste,y_pred = y_prev_teste,digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#         Asia     0.4400    0.5500    0.4889        20
#       Europe     0.4737    0.5294    0.5000        17
#          USA     0.9259    0.8197    0.8696        61
#
#     accuracy                         0.7143        98
#    macro avg     0.6132    0.6330    0.6195        98
# weighted avg     0.7483    0.7143    0.7278        98

# %% [markdown]
# ## **6)** Validação k-folds

# %%
# Importação da bilioteca necessária
from sklearn.model_selection import cross_val_score

# Parâmetros da função 'cross_val_score':
#   estimator = estimador de alguma classe reconhecida (Scikit-Learn)
#   X,y = atributos (X) e resposta (y)
#   cv = número [inteiro] de partições (k); valor padrão: k = 5
#   scoring = texto indicativo da métrica de qualidade a ser calculada (teste)
#     https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-string-names
#
# Retorno:
#   array (Numpy) com os k valores da métrica selecionada

# Executa a validação cruzada k-folds, com k = 5, avaliando a métrica de acurácia
aval = cross_val_score(clf_KNN,X_treino_Padr,y_treino,cv = 5,scoring = 'accuracy')

# Calcula o coeficiente de variação das avaliações = desvio padrão/média
# Critério:
# Até 20%: variação baixa
# De 20% a 60%: variação moderada
# Acima de 60%: variação alta

print("Valores de acurácia obtidos:",aval)
print("")   # "Imprime" uma linha em branco
print("Acurácia médio =",aval.mean())
print("Coeficiente de variação (%) =",100*aval.std(ddof = 1)/aval.mean())
# Out:
# Valores de acurácia obtidos: [0.69491525 0.71186441 0.71186441 0.74576271 0.75862069]
#
# Acurácia médio = 0.724605493863238
# Coeficiente de variação (%) = 3.658361566181727

# %% [markdown]
# # **Exercício 4** Acurácia em função do numero de vizinhos para o classificador *KNN*

# %%
# variando k entre 2 e 10, treinar o classificador KNN e avaliar a acurácia média
# da validação k-folds

# Lista para armazenar as acurácias médias para cada valor de K
mean_accuracies = []

# Iterar sobre os valores de K de 2 a 10
for k in range(2, 11):
    # Criar uma instância do classificador KNN com o valor de K atual
    clf_KNN = KNeighborsClassifier(n_neighbors=k)

    # Executar a validação cruzada k-folds (com k=5) para o classificador KNN
    aval_knn = cross_val_score(clf_KNN, X_treino_Padr, y_treino, cv=5, scoring='accuracy')

    # Calcular a acurácia média para o valor de K atual e adicionar à lista
    mean_accuracies.append(aval_knn.mean())

# Exibir as acurácias médias para cada valor de K
for i, acc in enumerate(mean_accuracies):
    print(f"K = {i + 2}: Acurácia média = {acc:.4f}")
# Out:
# K = 2: Acurácia média = 0.7177
# K = 3: Acurácia média = 0.7043
# K = 4: Acurácia média = 0.7077
# K = 5: Acurácia média = 0.7246
# K = 6: Acurácia média = 0.7316
# K = 7: Acurácia média = 0.7314
# K = 8: Acurácia média = 0.7348
# K = 9: Acurácia média = 0.7280
# K = 10: Acurácia média = 0.7347

# %% [markdown]
# final do ex 3
